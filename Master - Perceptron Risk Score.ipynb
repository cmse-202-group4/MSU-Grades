# %%
import pandas as pd
import numpy as np

grades_final = pd.read_csv('new_grades_statistics')

grades_test['date'] =  pd.to_datetime(grades_test['date'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-6d267308a3b5> in <module>
#       2 import numpy as np
#       3
# ----> 4 grades_final = pd.read_csv('new_grades_statistics')
#       5
#       6 grades_test['date'] =  pd.to_datetime(grades_test['date'])
#
# ...

# %%
probability_lists = []

for i in range(46191):
    if i == 0:
        probability_lists.append(grades_test['probability'][:8].values)
    else:
        probability_lists.append(grades_test['probability'][i * 8:8 * (i+1)].values)
        
probability_lists

# %%
grades_test['gpa_grade_values'] = [[4, 3.5, 3, 2.5, 2, 1.5, 1, 0]] * len(grades_test)
# Out:
#              date                                 unique_course_name semester  \
# 0      2014-12-15                AAAS_100__FS14___YOMAIRA C FIGUEROA     FS14
# 1      2015-12-15                AAAS_100__FS15___YOMAIRA C FIGUEROA     FS15
# 2      2016-12-15                    AAAS_100__FS16___XHERCIS MENDEZ     FS16
# 3      2017-12-15                    AAAS_100__FS17___XHERCIS MENDEZ     FS17
# 4      2018-12-15                   AAAS_100__FS18___TAMARA T BUTLER     FS18
# 5      2016-12-15               AAAS_300__FS16___GLENN A CHAMBERS JR     FS16
# 6      2017-12-15               AAAS_300__FS17___GLENN A CHAMBERS JR     FS17
# 7      2016-05-15              AAAS_390__SS16___TERRION L WILLIAMSON     SS16
# 8      2017-05-15                   AAAS_390__SS17___TAMARA T BUTLER     SS17
# 9      2018-05-15                   AAAS_390__SS18___TAMARA T BUTLER     SS18
# 10     2013-12-15                   AAAS_830__FS13___PERO G DAGBOVIE     FS13
# ...

# %% [markdown]
# # Please leave a cell space between work so we don't have merge conflicts

# %%
# J. Sheehan

# %%
# Austin Ader


grades_final['probability_lists'].values[0]
# Out:
# '[0.29166667 0.16666667 0.16666667 0.20833333 0.         0.04166667\n 0.04166667 0.08333333]'

# %%
# Li Han

# %%
# Austin C.
